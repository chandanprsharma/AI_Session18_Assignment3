# %% [markdown]
# ## Statistics 1
# ### Assignment 1 Question

# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Problem Statement 1:
# You survey households in your area to find the average rent they are paying. Find the standard deviation from the following data:
# ![Q1_input.JPG](attachment:Q1_input.JPG)

# %%
rent_list = [1550, 1700, 900, 850, 1000, 950]
print('Standard Deviation: ', np.std(rent_list))
# Out:
# Standard Deviation:  335.92740617910624

# %%
# Calculate Standard Deviation without using In-built function
# calculate mean
m = sum(rent_list) / len(rent_list)

# calculate variance using a list comprehension
var_res = sum((xi - m) ** 2 for xi in rent_list) / len(rent_list)
std = var_res ** .5
print('Standard Deviation: ', std)
# Out:
# Standard Deviation:  335.92740617910624

# %% [markdown]
# #### Problem Statement 2:
# Find the variance for the following set of data representing trees in California (heights in feet):
# 3, 21, 98, 203, 17, 9

# %%
trees_height = [3, 21, 98, 203, 17, 9]
print('Variance: ', np.var(trees_height))
# Out:
# Variance:  5183.25

# %%
# Calculate Variance without using In-built function
# calculate mean
m = sum(trees_height) / len(trees_height)

# calculate variance using a list comprehension
var_res = sum((xi - m) ** 2 for xi in trees_height) / len(trees_height)
print('Variance: ', var_res)
# Out:
# Variance:  5183.25

# %% [markdown]
# #### Problem Statement 3:
# In a class on 100 students, 80 students passed in all subjects, 10 failed in one subject, 7 failed in two subjects and 3 failed in three subjects. Find the probability distribution of the variable for number of subjects a student from the given class has failed in.

# %%
X = [0, 1, 2, 3]
p = [80/100, 10/100, 7/100, 3/100]

y_pos = np.arange(len(X))
plt.bar(y_pos, p, align='center', alpha=0.5)
plt.xticks(y_pos, X)
plt.ylabel('Failing Probability')
plt.xlabel('No. of Subject')
plt.title('Probability Distribution of number of subjects a student has failed')

plt.show()
